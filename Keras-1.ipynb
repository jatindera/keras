# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../keras/code/zero_to_deep_learning_udemy/data/weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.plot(kind='scatter', x='Height', y='Weight', title='Weight and Height in Adults')
plt.plot([55,78],[75,250],color='red',linewidth=3)

# %%
#Linear Regression y=mx+b. Here m is weight. So, we can say, y = wx + b or y = w * x + b

# %%
def myLinearRegression(x, w=0, b=0):
    return x * w + b
x = np.linspace(55,80,100)
yhat = myLinearRegression(x,w=0,b=0)
df.plot(kind='scatter',x='Height', y='Weight', title='Weight adn Height in Adults')
plt.plot(x,yhat,color='red', linewidth=3);

# %%
def mean_squared_error(y_true,y_pred):
    s = (y_true - y_pred) ** 2
    return s.mean()

# %%
X = df['Height'].values

# %%
X
# Out:
# array([73.84701702, 68.78190405, 74.11010539, ..., 63.86799221,
#        69.03424313, 61.94424588])

# %%
y_true = df['Weight'].values

# %%
y_true
# Out:
# array([241.89356318, 162.31047252, 212.74085556, ..., 128.47531878,
#        163.85246135, 113.64910268])

# %%
y_pred = myLinearRegression(X,w=2,b=30)

# %%
y_pred
# Out:
# array([177.69403404, 167.56380809, 178.22021078, ..., 157.73598443,
#        168.06848626, 153.88849176])

# %%
mean_squared_error(y_true,y_pred)
# Out:
# 634.8082110873438

# %%
#faster results #Costy Function

# %%
mean_squared_error(y_true,y_pred.ravel())
# Out:
# 634.8082110873438

# %%
df.plot(kind='scatter',x='Height', y='Weight', title='Weight adn Height in Adults')
plt.plot(X,y_pred,color='red', linewidth=3);

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam, SGD

# %%
model = Sequential()

# %%
model.add(Dense(1,input_shape(1,)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-350922b6a948> in <module>()
# ----> 1 model.add(Dense(1,input_shape(1,)))
#
# NameError: name 'input_shape' is not defined
